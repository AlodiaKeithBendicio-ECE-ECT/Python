# %% [markdown]
# # Portal Export

# %%
AH - 2 months
AHAERO - 3 months
AHCOMM - 1 year
AHDIAB - 1 year
AHQUIPT - 1 year

# %%
# JANUARY 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-01-01&DateRangeEnd=2025-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-01-01&DateRangeEnd=2024-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-04-01&DateRangeEnd=2024-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-09-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-01-01&DateRangeEnd=2024-02-28',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-03-01&DateRangeEnd=2024-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-08-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-10-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-01-31'
    ]
for link in file_links:
    driver.get(link)
    time.sleep(0.5)

print("DONE EXPORTING")

# driver.quit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 26
#      24 time.sleep(0.5)
#      25 driver.find_element(By.XPATH, "//button[@type='submit']").click()
# ---> 26 driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
#      27 time.sleep(0.5)
#      28 driver.get("https://portal.healthybos.com/Report/RawData")
#
# AttributeError: 'NoneType' object has no attribute 'click'

# %%
# FEBRUARY 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-02-01&DateRangeEnd=2025-02-28',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-02-01&DateRangeEnd=2024-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-07-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-10-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-02-28',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-02-01&DateRangeEnd=2024-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-04-01&DateRangeEnd=2024-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-07-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-09-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-12-01&DateRangeEnd=2025-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-02-28'
    ]
for link in file_links:
    driver.get(link)
    time.sleep(0.5)

print("DONE EXPORTING")

# driver.quit()
# Out:
# DONE EXPORTING

# %%
# MARCH 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-03-01&DateRangeEnd=2025-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-03-01&DateRangeEnd=2024-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-08-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-12-01&DateRangeEnd=2025-02-28',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-03-01&DateRangeEnd=2024-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-08-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-10-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-02-28',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-03-31'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(0.5)

print("DONE EXPORTING")

# driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[2], line 21
#      19 driver.verificationErrors = []
#      20 driver.accept_next_alert = True
# ---> 21 driver.get("https://portal.healthybos.com/User/login")
#      22 driver.find_element("id", "username").send_keys("Alodia.Bendicio@healthybos.com")
#      23 driver.find_element("id", "password").send_keys("BendiciO_041001")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:363, in WebDriver.get(self, url)
#     361 def get(self, url: str) -> None:
#     362     """Loads a web page in the current browser session."""
# --> 363     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
# ...

# %%
# APRIL 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-04-01&DateRangeEnd=2025-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-04-01&DateRangeEnd=2024-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-09-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-04-01&DateRangeEnd=2024-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-07-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-09-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-04-30'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# MAY 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2025-05-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-07-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2025-01-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-04-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-05-01&DateRangeEnd=2025-05-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-06-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-02-28',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-04-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-05-01&DateRangeEnd=2025-05-31'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# JUNE 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2025-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-08-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-02-28',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-06-01&DateRangeEnd=2025-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-07-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-09-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-06-01&DateRangeEnd=2025-06-30'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# JULY 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2025-07-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-03-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-06-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-07-01&DateRangeEnd=2025-07-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-02-28',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-04-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-05-01&DateRangeEnd=2025-06-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-07-01&DateRangeEnd=2025-07-31'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[1], line 26
#      24 time.sleep(0.5)
#      25 driver.find_element(By.XPATH, "//button[@type='submit']").click()
# ---> 26 driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
#      27 time.sleep(0.5)
#      28 driver.get("https://portal.healthybos.com/Report/RawData")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
# ...

# %%
# AUGUST 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2025-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2025-01-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-04-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-05-01&DateRangeEnd=2025-07-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-08-01&DateRangeEnd=2025-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-01-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-03-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-05-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-06-01&DateRangeEnd=2025-07-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-08-01&DateRangeEnd=2025-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHDIA2&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=Quipt&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-12-31'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# SEPTEMBER 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path=r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2025-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-11-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-02-28',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-05-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-06-01&DateRangeEnd=2025-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-09-01&DateRangeEnd=2025-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-02-28',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-03-01&DateRangeEnd=2025-04-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-05-01&DateRangeEnd=2025-06-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-07-01&DateRangeEnd=2025-08-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-09-01&DateRangeEnd=2025-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHDIA2&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=Quipt&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-12-31'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# OCTOBER 2025

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path=r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2025-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-03-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-06-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-07-01&DateRangeEnd=2025-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-10-01&DateRangeEnd=2025-10-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-01-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-03-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-05-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-06-01&DateRangeEnd=2025-07-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-08-01&DateRangeEnd=2025-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-10-01&DateRangeEnd=2025-09-30',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHDIA2&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-12-31',
    'https://portal.knackrcm.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=Quipt&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-01-01&DateRangeEnd=2025-12-31'
    ]
    
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# NOVEMBER 2024

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2023-11-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2023-11-01&DateRangeEnd=2024-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-02-01&DateRangeEnd=2024-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-07-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-10-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2023-11-01&DateRangeEnd=2023-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-01-01&DateRangeEnd=2024-02-29',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-03-01&DateRangeEnd=2024-04-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-05-01&DateRangeEnd=2024-06-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-07-01&DateRangeEnd=2024-08-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-10-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-11-01&DateRangeEnd=2024-11-30'
    ]
for link in file_links:
    driver.get(link)
    time.sleep(60)

print("DONE EXPORTING")

driver.quit()
# Out:
# DONE EXPORTING

# %%
# DECEMBER 2024

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("")
driver.find_element("id", "password").send_keys("")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHCOMM&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2023-12-01&DateRangeEnd=2024-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2023-12-01&DateRangeEnd=2024-02-29',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-03-01&DateRangeEnd=2024-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-08-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-09-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AHAERO&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2024-12-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2023-12-01&DateRangeEnd=2024-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-02-01&DateRangeEnd=2024-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-04-01&DateRangeEnd=2024-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-06-01&DateRangeEnd=2024-07-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-08-01&DateRangeEnd=2024-09-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2024-12-31'
    ]
for link in file_links:
    driver.get(link)
    time.sleep(0.5)

print("DONE EXPORTING")

# driver.quit()
# Out:
# DONE EXPORTING

# %%
# EXPORT SPECIFIC ONLY

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
import sys
driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
service = Service(driver_path)
driver = webdriver.Chrome(service=service)
driver.implicitly_wait(30)
driver.verificationErrors = []
driver.accept_next_alert = True
driver.get("https://portal.healthybos.com/User/login")
driver.find_element("id", "username").send_keys("insert username")
driver.find_element("id", "password").send_keys("insert password")
time.sleep(0.5)
driver.find_element(By.XPATH, "//button[@type='submit']").click()
driver.find_element(By.XPATH, "//nav[@id='page-leftbar']//span[text()='Reports']").click()
time.sleep(0.5)
driver.get("https://portal.healthybos.com/Report/RawData")
# driver.find_element(By.LINK_TEXT, "Raw Data").click()
time.sleep(0.5)
file_links = [
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-10-01&DateRangeEnd=2024-11-30',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2024-12-01&DateRangeEnd=2025-01-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-02-01&DateRangeEnd=2025-03-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-04-01&DateRangeEnd=2025-05-31',
    'https://portal.healthybos.com/Report/RawData.xlsx?offset=0&limit=1000000&Client%5B%5D=AH&SubClient%5B%5D=&Status=&SubStatus=&SearchDateType=1&DateRangeStart=2025-06-01&DateRangeEnd=2025-06-30'
    ]
for link in file_links:
    driver.get(link)
    time.sleep(5)

print("DONE EXPORTING")

# driver.quit()
# Out:
# DONE EXPORTING
