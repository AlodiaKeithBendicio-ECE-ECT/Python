# %% [markdown]
# ### HELD Prod Analysis - SnapHeld
# - SEARCH TERM SHOULD BE UNIQUE CODE THAT SERVES AS THE IDENTIFIER OF THE DOWNLOADED FILES
# - LIMITATION - ANY FILE CONTAINING THE SEARCH TERM WILL BE DELETED OR MOVED

# %% [markdown]
# # TUESDAY - FRIDAY CODE

# %%
# CODE FOR TUESDAY - FRIDAY (Yesterday's Data i.e. -1)

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
from datetime import datetime, timedelta
import sys
import os
import shutil
import glob
import ipywidgets as widgets
from IPython.display import display, clear_output

# Download Folder Path
download_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads") # Expands to the user's Downloads directory
held_prod_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads\HELD PROD CAMP FILES")  # Expands to the user's "held folder" directory.  Adjust if your path is different.

# DELETE ALL FILES IN HELD PROD CAMP FILES folder
search_terms = ["heldprod"]
def delete_excel_files(search_terms, held_prod_path):
    try:
        if not os.path.exists(held_prod_path):
            print(f"Error: Downloads folder not found at {held_prod_path}")
            return
        for term in search_terms:
            # Use glob with a wildcard to find Excel files (both .csv and .csv)
            pattern = os.path.join(held_prod_path, f"*{term}*.csv*")  # Matches .csv, .csv, etc.
            files_to_delete = glob.glob(pattern)
            if files_to_delete:
                print(f"Found files containing '{term}':")
                for file_path in files_to_delete:
                    print(f"- {file_path}")
                    try:
                        os.remove(file_path)
                        print(f"  Deleted: {file_path}")
                    except OSError as e:
                        print(f"  Error deleting {file_path}: {e}")
            else:
                print(f"No files found containing '{term}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

delete_excel_files(search_terms, held_prod_path)

# Get Recent File to Rename
def get_most_recent_file(folder_path, timeout=30):
    start_time = time.time()
    while time.time() - start_time < timeout:
        files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if not f.endswith(".crdownload")]
        if files:
            most_recent_file = max(files, key=os.path.getmtime)  # Get the latest modified file
            return most_recent_file
        time.sleep(1)  # Wait a second before re-checking
    raise Exception("No file was downloaded within the timeout period.")

# XPATH
xpath = "//*[@id='DataTables_Table_0']/tbody/tr[1]/td[4]/a"

# CAMPAIGN Links
a = "https://manage.callshaper.com/CampaignExport/history/3593/8806"
b = "https://manage.callshaper.com/CampaignExport/history/3205/8807"
c = "https://manage.callshaper.com/CampaignExport/history/1396/8808"
d = "https://manage.callshaper.com/CampaignExport/history/3094/8809"
e = "https://manage.callshaper.com/CampaignExport/history/2345/8810"
f = "https://manage.callshaper.com/CampaignExport/history/2312/8811"
g = "https://manage.callshaper.com/CampaignExport/history/3036/8812"
h = "https://manage.callshaper.com/CampaignExport/history/2175/8813"
i = "https://manage.callshaper.com/CampaignExport/history/2410/8819"
j = "https://manage.callshaper.com/CampaignExport/history/2403/8814"
k = "https://manage.callshaper.com/CampaignExport/history/667/8815"
l = "https://manage.callshaper.com/CampaignExport/history/1278/8816"
m = "https://manage.callshaper.com/CampaignExport/history/396/8817"

# CAMPAIGN NAMES
camp1 = "heldprod AH SnapHeld Aging Prod"
camp2 = "heldprod AH SnapHeld ARM Prod"
camp3 = "heldprod AH SnapHeld DCAH Prod"
camp4 = "heldprod AH SnapHeld DCScrubs Prod"
camp5 = "heldprod AH SnapHeld Edocument Prod"
camp6 = "heldprod AH SnapHeld PTCall Prod"
camp7 = "heldprod AH SnapHeld Rework Prod"
camp8 = "heldprod AH SnapHeld Special Project - Billable"
camp9 = "heldprod AH SnapHeld Special Project - NonBillable"
camp10 = "heldprod AH SnapHeld VSA Prod"
camp11 = "heldprod HBOSS Portal Doctor Research"
camp12 = "heldprod HBOSS Portal Fax Mapping"
camp13 = "heldprod HBOSS Portal Fax Research"

try:
    driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
    service = Service(driver_path)
    driver = webdriver.Chrome(service=service)
    driver.implicitly_wait(30)
    driver.verificationErrors = []
    driver.accept_next_alert = True
# Enter the link to access and credentials
    driver.get("https://manage.callshaper.com/Report/Team")
    driver.find_element("id", "email").send_keys("*insert email")
    driver.find_element("id", "password").send_keys("*insert password*")
    time.sleep(0.5)
    driver.find_element(By.XPATH, "//button[@class='btn btn-inverse']").click()  # use XPATH -> add "//" -> change to single quotes "''" inside bracket
    time.sleep(0.5)
    print("Successful CDP Log In")
    
# CAMPAIGNS

# 1. AH-SnapHeld-Aging-Prod
    driver.get(a)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp1 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp1}'")

# 2. AH-SnapHeld-ARM-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    print("Switch to the new tab")
    driver.get(b)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp2 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp2}'")

# 3. AH-SnapHeld-DCAH-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[2])
    print("Switch to the new tab")
    driver.get(c)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp3 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp3}'")
    
# 4. AH-SnapHeld-DCScrubs-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[3])
    print("Switch to the new tab")
    driver.get(d)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp4 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp4}'")

# 5. AH-SnapHeld-Edocument-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[4])
    print("Switch to the new tab")
    driver.get(e)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp5 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp5}'")

# 6. AH-SnapHeld-PTCall-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[5])
    print("Switch to the new tab")
    driver.get(f)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp6 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp6}'")

# 7. AH-SnapHeld-Rework-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[6])
    print("Switch to the new tab")
    driver.get(g)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp7 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp7}'")

# 8. AH-SnapHeld-Special Project - Billable
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[7])
    print("Switch to the new tab")
    driver.get(h)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp8 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp8}'")

# 9. AH-SnapHeld-Special Project - NonBillable
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[8])
    print("Switch to the new tab")
    driver.get(i)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp9 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp9}'")

# 10. AH-SnapHeld-VSA-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[9])
    print("Switch to the new tab")
    driver.get(j)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp10 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp10}'")

# 11. HBOSS Portal Doctor Research
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[10])
    print("Switch to the new tab")
    driver.get(k)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp11 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp11}'")

# 12. HBOSS Portal Fax Mapping
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[11])
    print("Switch to the new tab")
    driver.get(l)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp12 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp12}'")

# 13. HBOSS Portal Fax Research
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[12])
    print("Switch to the new tab")
    driver.get(m)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp13 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp13}'")

    
    print("Done Exporting 13 Held Camp Files")


except Exception as e:
   print(f"An error occurred: {e}")
# finally:
#  driver.quit()

# MOVE FILES TO HELD PROD CAMP FILES FOLDER

# Use glob to find files containing "AH" (case-insensitive)
search_pattern = os.path.join(download_path, "*heldprod*") # * is a wildcard
files_to_move = glob.glob(search_pattern)
# Alternative using list comprehension and os.listdir for more control over case sensitivity or other matching criteria
# files_in_downloads = os.listdir(download_path)
# files_to_move = [os.path.join(download_path, f) for f in files_in_downloads if "ah" in f.lower()] # Case-insensitive search


if files_to_move:
    print(f"Found {len(files_to_move)} files to move:")
    for file_path in files_to_move:
        print(f" - {file_path}")

        try:
            # Extract just the filename for the destination path
            file_name = os.path.basename(file_path)
            destination_path = os.path.join(held_prod_path, file_name)

            # Move the file
            shutil.move(file_path, destination_path)
            print(f"Moved '{file_name}' to '{held_prod_path}'")

        except Exception as e:
            print(f"Error moving '{file_path}': {e}")

else:
    print("No files found matching the criteria.")


# # Example of how to handle different cases of "ah"
# search_pattern_case_insensitive = os.path.join(download_path, "*[Aa][Hh]*") # Matches AH, ah, Ah, aH
# files_to_move_case_insensitive = glob.glob(search_pattern_case_insensitive)

# ... (rest of the code for moving the files is the same, just use files_to_move_case_insensitive)

yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y%m%d')
print(f"DONE " + yesterday)

'''
Note:
    - F12 (HTML) -> DRAG Pointer -> COPY -> Right Click -> Copy -> Copy XPath
'''
# Out:
# No files found containing 'heldprod'.
# Successful CDP Log In
# Succesfully downloaded 'heldprod AH SnapHeld Aging Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld ARM Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld DCAH Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld DCScrubs Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld Edocument Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld PTCall Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld Rework Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld Special Project - Billable'
# Switch to the new tab
# Succesfully downloaded 'heldprod AH SnapHeld VSA Prod'
# Switch to the new tab
# Succesfully downloaded 'heldprod HBOSS Portal Doctor Research'
# Switch to the new tab
# Succesfully downloaded 'heldprod HBOSS Portal Fax Mapping'
# ...

# %% [markdown]
# # MONDAY CODE

# %%
# CODE FOR MONDAY (Friday's Data i.e. -3)

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
from datetime import datetime, timedelta
import sys
import os
import shutil
import glob
import ipywidgets as widgets
from IPython.display import display, clear_output

# Download Folder Path
download_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads") # Expands to the user's Downloads directory
held_prod_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads\HELD PROD CAMP FILES")  # Expands to the user's "held folder" directory.  Adjust if your path is different.

# DELETE ALL FILES IN HELD PROD CAMP FILES folder
search_terms = ["heldprod"]
def delete_excel_files(search_terms, held_prod_path):
    try:
        if not os.path.exists(held_prod_path):
            print(f"Error: Downloads folder not found at {held_prod_path}")
            return
        for term in search_terms:
            # Use glob with a wildcard to find Excel files (both .csv and .csv)
            pattern = os.path.join(held_prod_path, f"*{term}*.csv*")  # Matches .csv, .csv, etc.
            files_to_delete = glob.glob(pattern)
            if files_to_delete:
                print(f"Found files containing '{term}':")
                for file_path in files_to_delete:
                    print(f"- {file_path}")
                    try:
                        os.remove(file_path)
                        print(f"  Deleted: {file_path}")
                    except OSError as e:
                        print(f"  Error deleting {file_path}: {e}")
            else:
                print(f"No files found containing '{term}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

delete_excel_files(search_terms, held_prod_path)

# Get Recent File to Rename
def get_most_recent_file(folder_path, timeout=30):
    start_time = time.time()
    while time.time() - start_time < timeout:
        files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if not f.endswith(".crdownload")]
        if files:
            most_recent_file = max(files, key=os.path.getmtime)  # Get the latest modified file
            return most_recent_file
        time.sleep(1)  # Wait a second before re-checking
    raise Exception("No file was downloaded within the timeout period.")

# XPATH
xpath = "//*[@id='DataTables_Table_0']/tbody/tr[3]/td[4]/a"

# CAMPAIGN Links
a = "https://manage.callshaper.com/CampaignExport/history/3593/8806"
b = "https://manage.callshaper.com/CampaignExport/history/3205/8807"
c = "https://manage.callshaper.com/CampaignExport/history/1396/8808"
d = "https://manage.callshaper.com/CampaignExport/history/3094/8809"
e = "https://manage.callshaper.com/CampaignExport/history/2345/8810"
f = "https://manage.callshaper.com/CampaignExport/history/2312/8811"
g = "https://manage.callshaper.com/CampaignExport/history/3036/8812"
h = "https://manage.callshaper.com/CampaignExport/history/2175/8813"
i = "https://manage.callshaper.com/CampaignExport/history/2410/8819"
j = "https://manage.callshaper.com/CampaignExport/history/2403/8814"
k = "https://manage.callshaper.com/CampaignExport/history/667/8815"
l = "https://manage.callshaper.com/CampaignExport/history/1278/8816"
m = "https://manage.callshaper.com/CampaignExport/history/396/8817"

# CAMPAIGN NAMES
camp1 = "heldprod AH SnapHeld Aging Prod"
camp2 = "heldprod AH SnapHeld ARM Prod"
camp3 = "heldprod AH SnapHeld DCAH Prod"
camp4 = "heldprod AH SnapHeld DCScrubs Prod"
camp5 = "heldprod AH SnapHeld Edocument Prod"
camp6 = "heldprod AH SnapHeld PTCall Prod"
camp7 = "heldprod AH SnapHeld Rework Prod"
camp8 = "heldprod AH SnapHeld Special Project - Billable"
camp9 = "heldprod AH SnapHeld Special Project - NonBillable"
camp10 = "heldprod AH SnapHeld VSA Prod"
camp11 = "heldprod HBOSS Portal Doctor Research"
camp12 = "heldprod HBOSS Portal Fax Mapping"
camp13 = "heldprod HBOSS Portal Fax Research"

try:
    driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
    service = Service(driver_path)
    driver = webdriver.Chrome(service=service)
    driver.implicitly_wait(30)
    driver.verificationErrors = []
    driver.accept_next_alert = True
# Enter the link to access and credentials
    driver.get("https://manage.callshaper.com/Report/Team")
    driver.find_element("id", "email").send_keys("*insert email")
    driver.find_element("id", "password").send_keys("*insert password*")
    time.sleep(0.5)
    driver.find_element(By.XPATH, "//button[@class='btn btn-inverse']").click()  # use XPATH -> add "//" -> change to single quotes "''" inside bracket
    time.sleep(0.5)
    print("Successful CDP Log In")
    
# CAMPAIGNS

# 1. AH-SnapHeld-Aging-Prod
    driver.get(a)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp1 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp1}'")

# 2. AH-SnapHeld-ARM-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    print("Switch to the new tab")
    driver.get(b)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp2 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp2}'")

# 3. AH-SnapHeld-DCAH-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[2])
    print("Switch to the new tab")
    driver.get(c)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp3 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp3}'")
    
# 4. AH-SnapHeld-DCScrubs-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[3])
    print("Switch to the new tab")
    driver.get(d)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp4 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp4}'")

# 5. AH-SnapHeld-Edocument-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[4])
    print("Switch to the new tab")
    driver.get(e)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp5 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp5}'")

# 6. AH-SnapHeld-PTCall-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[5])
    print("Switch to the new tab")
    driver.get(f)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp6 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp6}'")

# 7. AH-SnapHeld-Rework-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[6])
    print("Switch to the new tab")
    driver.get(g)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp7 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp7}'")

# 8. AH-SnapHeld-Special Project - Billable
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[7])
    print("Switch to the new tab")
    driver.get(h)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp8 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp8}'")

# 9. AH-SnapHeld-Special Project - NonBillable
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[8])
    print("Switch to the new tab")
    driver.get(i)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp9 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp9}'")

# 10. AH-SnapHeld-VSA-Prod
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[9])
    print("Switch to the new tab")
    driver.get(j)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp10 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp10}'")

# 11. HBOSS Portal Doctor Research
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[10])
    print("Switch to the new tab")
    driver.get(k)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp11 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp11}'")

# 12. HBOSS Portal Fax Mapping
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[11])
    print("Switch to the new tab")
    driver.get(l)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp12 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp12}'")

# 13. HBOSS Portal Fax Research
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[12])
    print("Switch to the new tab")
    driver.get(m)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp13 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp13}'")

    
    print("Done Exporting 13 Held Camp Files")


except Exception as e:
   print(f"An error occurred: {e}")
# finally:
#  driver.quit()

# MOVE FILES TO HELD PROD CAMP FILES FOLDER

# Use glob to find files containing "AH" (case-insensitive)
search_pattern = os.path.join(download_path, "*heldprod*") # * is a wildcard
files_to_move = glob.glob(search_pattern)
# Alternative using list comprehension and os.listdir for more control over case sensitivity or other matching criteria
# files_in_downloads = os.listdir(download_path)
# files_to_move = [os.path.join(download_path, f) for f in files_in_downloads if "ah" in f.lower()] # Case-insensitive search


if files_to_move:
    print(f"Found {len(files_to_move)} files to move:")
    for file_path in files_to_move:
        print(f" - {file_path}")

        try:
            # Extract just the filename for the destination path
            file_name = os.path.basename(file_path)
            destination_path = os.path.join(held_prod_path, file_name)

            # Move the file
            shutil.move(file_path, destination_path)
            print(f"Moved '{file_name}' to '{held_prod_path}'")

        except Exception as e:
            print(f"Error moving '{file_path}': {e}")

else:
    print("No files found matching the criteria.")


# # Example of how to handle different cases of "ah"
# search_pattern_case_insensitive = os.path.join(download_path, "*[Aa][Hh]*") # Matches AH, ah, Ah, aH
# files_to_move_case_insensitive = glob.glob(search_pattern_case_insensitive)

# ... (rest of the code for moving the files is the same, just use files_to_move_case_insensitive)

friday = (datetime.now() - timedelta(days=3)).strftime('%Y%m%d')
print(f"DONE " + friday)

'''
Note:
    - F12 (HTML) -> DRAG Pointer -> COPY -> Right Click -> Copy -> Copy XPath
'''
# Out:
# No files found containing 'heldprod'.
# Successful CDP Log In
# An error occurred: 'NoneType' object has no attribute 'click'
# No files found matching the criteria.
# DONE 20251003
# '\nNote:\n    - F12 (HTML) -> DRAG Pointer -> COPY -> Right Click -> Copy -> Copy XPath\n'
