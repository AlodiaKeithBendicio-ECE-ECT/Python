# %% [markdown]
# ### DIAB Prod Analysis
# - SEARCH TERM SHOULD BE UNIQUE CODE THAT SERVES AS THE IDENTIFIER OF THE DOWNLOADED FILES
# - LIMITATION - ANY FILE CONTAINING THE SEARCH TERM WILL BE DELETED OR MOVED
# - .xlsx -> .csv

# %% [markdown]
# # TUESDAY - FRIDAY CODE

# %%
# CODE FOR TUESDAY - FRIDAY (Yesterday's Data i.e. -1)

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
from datetime import datetime, timedelta
import sys
import os
import shutil
import glob
import ipywidgets as widgets
from IPython.display import display, clear_output

# Download Folder Path
download_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads") # Expands to the user's Downloads directory
diab_prod_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads\DIAB PROD CAMP FILES")  # Expands to the user's "held folder" directory.  Adjust if your path is different.

# DELETE ALL FILES IN DIAB PROD CAMP FILES folder
search_terms = ["diabprod"]
def delete_excel_files(search_terms, diab_prod_path):
    try:
        if not os.path.exists(diab_prod_path):
            print(f"Error: Downloads folder not found at {diab_prod_path}")
            return
        for term in search_terms:
            pattern = os.path.join(diab_prod_path, f"*{term}*.csv*") 
            files_to_delete = glob.glob(pattern)
            if files_to_delete:
                print(f"Found files containing '{term}':")
                for file_path in files_to_delete:
                    print(f"- {file_path}")
                    try:
                        os.remove(file_path)
                        print(f"  Deleted: {file_path}")
                    except OSError as e:
                        print(f"  Error deleting {file_path}: {e}")
            else:
                print(f"No files found containing '{term}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

delete_excel_files(search_terms, diab_prod_path)

# Get Recent File to Rename
def get_most_recent_file(folder_path, timeout=30):
    start_time = time.time()
    while time.time() - start_time < timeout:
        files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if not f.endswith(".crdownload")]
        if files:
            most_recent_file = max(files, key=os.path.getmtime)  # Get the latest modified file
            return most_recent_file
        time.sleep(1)  # Wait a second before re-checking
    raise Exception("No file was downloaded within the timeout period.")

# XPATH
xpath = "//*[@id='DataTables_Table_0']/tbody/tr[1]/td[4]/a"

# CAMPAIGN Links
k = "https://manage.callshaper.com/CampaignExport/history/5798/8744"
l = "https://manage.callshaper.com/CampaignExport/history/5806/8742"
m = "https://manage.callshaper.com/CampaignExport/history/5523/8096"
n = "https://manage.callshaper.com/CampaignExport/history/5092/7183"
o = "https://manage.callshaper.com/CampaignExport/history/5097/7225"
p = "https://manage.callshaper.com/CampaignExport/history/5093/7185"
q = "https://manage.callshaper.com/CampaignExport/history/5574/8135"
r = "https://manage.callshaper.com/CampaignExport/history/5094/7317"

# CAMPAIGN NAMES
camp11 = "diabprod DIAB Parachute"
camp12 = "diabprod DIAB VSA"
camp13 = "diabprod DIAB BT Load"
camp14 = "diabprod DIAB Dr Calls"
camp15 = "diabprod DIAB Medical Notes"
camp16 = "diabprod DIAB Patient Calls"
camp17 = "diabprod DIAB Held Aging"
camp18 = "diabprod DIAB Rework"

try:
    driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
    service = Service(driver_path)
    driver = webdriver.Chrome(service=service)
    driver.implicitly_wait(30)
    driver.verificationErrors = []
    driver.accept_next_alert = True
# Enter the link to access and credentials
    driver.get("https://manage.callshaper.com/Report/Team")
    driver.find_element("id", "email").send_keys("*insert email")
    driver.find_element("id", "password").send_keys("*insert password*")
    time.sleep(0.5)
    driver.find_element(By.XPATH, "//button[@class='btn btn-inverse']").click()  # use XPATH -> add "//" -> change to single quotes "''" inside bracket
    time.sleep(0.5)
    print("Successful CDP Log In")
    
# CAMPAIGNS

# 11. DIAB Parachute
    driver.get(k)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp11 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp11}'")

# 12. DIAB VSA
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    print("Switch to the new tab")
    driver.get(l)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp12 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp12}'")

# 13. DIAB BT Load
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[2])
    print("Switch to the new tab")
    driver.get(m)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp13 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp13}'")
    
# 14. DIAB Dr Calls
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[3])
    print("Switch to the new tab")
    driver.get(n)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp14 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp14}'")
    
# 15. DIAB Medical Notes
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[4])
    print("Switch to the new tab")
    driver.get(o)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp15 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp15}'")

# 16. DIAB Patient Calls
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[5])
    print("Switch to the new tab")
    driver.get(p)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp16 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp16}'")

# 17. DIAB Held Aging
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[6])
    print("Switch to the new tab")
    driver.get(q)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp17 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp17}'")

# 18. DIAB Rework
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[7])
    print("Switch to the new tab")
    driver.get(r)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp18 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp18}'")

    print("Done Exporting 8 DIAB Prod Files")


except Exception as e:
   print(f"An error occurred: {e}")
# finally:
#  driver.quit()

# MOVE FILES TO HELD PROD CAMP FILES FOLDER

# Use glob to find files containing "AH" (case-insensitive)
search_pattern = os.path.join(download_path, "*diabprod*") # * is a wildcard
files_to_move = glob.glob(search_pattern)


if files_to_move:
    print(f"Found {len(files_to_move)} files to move:")
    for file_path in files_to_move:
        print(f" - {file_path}")

        try:
            # Extract just the filename for the destination path
            file_name = os.path.basename(file_path)
            destination_path = os.path.join(diab_prod_path, file_name)

            # Move the file
            shutil.move(file_path, destination_path)
            print(f"Moved '{file_name}' to '{diab_prod_path}'")

        except Exception as e:
            print(f"Error moving '{file_path}': {e}")

else:
    print("No files found matching the criteria.")

yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y%m%d')
print(f"DONE " + yesterday)
# Out:
# Found files containing 'diabprod':
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB BT Load.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB BT Load.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Dr Calls.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Dr Calls.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Held Aging.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Held Aging.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Medical Notes.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Medical Notes.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Parachute.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Parachute.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Patient Calls.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Patient Calls.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Rework.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Rework.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB VSA.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB VSA.csv
# Successful CDP Log In
# Succesfully downloaded 'diabprod DIAB Parachute'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB VSA'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB BT Load'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Dr Calls'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Medical Notes'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Patient Calls'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Held Aging'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Rework'
# Done Exporting 4 DIAB Prod Files
# Found 8 files to move:
#  - C:/Users/Administrator/Downloads\diabprod DIAB BT Load.csv
# Moved 'diabprod DIAB BT Load.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Dr Calls.csv
# Moved 'diabprod DIAB Dr Calls.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Held Aging.csv
# Moved 'diabprod DIAB Held Aging.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Medical Notes.csv
# Moved 'diabprod DIAB Medical Notes.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Parachute.csv
# Moved 'diabprod DIAB Parachute.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Patient Calls.csv
# Moved 'diabprod DIAB Patient Calls.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Rework.csv
# Moved 'diabprod DIAB Rework.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB VSA.csv
# Moved 'diabprod DIAB VSA.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
# DONE 20250901

# %% [markdown]
# # MONDAY CODE

# %%
# CODE FOR MONDAY (Friday's Data i.e. -3)

import selenium
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import NoAlertPresentException
import unittest, time, re
import getpass
import datetime
from datetime import datetime, timedelta
import sys
import os
import shutil
import glob
import ipywidgets as widgets
from IPython.display import display, clear_output

# Download Folder Path
download_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads") # Expands to the user's Downloads directory
diab_prod_path = os.path.expanduser(r"C:\Users\Alodia Bendicio\Downloads\DIAB PROD CAMP FILES")  # Expands to the user's "held folder" directory.  Adjust if your path is different.

# DELETE ALL FILES IN DIAB PROD CAMP FILES folder
search_terms = ["diabprod"]
def delete_excel_files(search_terms, diab_prod_path):
    try:
        if not os.path.exists(diab_prod_path):
            print(f"Error: Downloads folder not found at {diab_prod_path}")
            return
        for term in search_terms:
            pattern = os.path.join(diab_prod_path, f"*{term}*.csv*") 
            files_to_delete = glob.glob(pattern)
            if files_to_delete:
                print(f"Found files containing '{term}':")
                for file_path in files_to_delete:
                    print(f"- {file_path}")
                    try:
                        os.remove(file_path)
                        print(f"  Deleted: {file_path}")
                    except OSError as e:
                        print(f"  Error deleting {file_path}: {e}")
            else:
                print(f"No files found containing '{term}'.")
    except Exception as e:
        print(f"An error occurred: {e}")

delete_excel_files(search_terms, diab_prod_path)

# Get Recent File to Rename
def get_most_recent_file(folder_path, timeout=30):
    start_time = time.time()
    while time.time() - start_time < timeout:
        files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if not f.endswith(".crdownload")]
        if files:
            most_recent_file = max(files, key=os.path.getmtime)  # Get the latest modified file
            return most_recent_file
        time.sleep(1)  # Wait a second before re-checking
    raise Exception("No file was downloaded within the timeout period.")

# XPATH
xpath = "//*[@id='DataTables_Table_0']/tbody/tr[3]/td[4]/a"

# CAMPAIGN Links
k = "https://manage.callshaper.com/CampaignExport/history/5798/8744"
l = "https://manage.callshaper.com/CampaignExport/history/5806/8742"
m = "https://manage.callshaper.com/CampaignExport/history/5523/8096"
n = "https://manage.callshaper.com/CampaignExport/history/5092/7183"
o = "https://manage.callshaper.com/CampaignExport/history/5097/7225"
p = "https://manage.callshaper.com/CampaignExport/history/5093/7185"
q = "https://manage.callshaper.com/CampaignExport/history/5574/8135"
r = "https://manage.callshaper.com/CampaignExport/history/5094/7317"

# CAMPAIGN NAMES
camp11 = "diabprod DIAB Parachute"
camp12 = "diabprod DIAB VSA"
camp13 = "diabprod DIAB BT Load"
camp14 = "diabprod DIAB Dr Calls"
camp15 = "diabprod DIAB Medical Notes"
camp16 = "diabprod DIAB Patient Calls"
camp17 = "diabprod DIAB Held Aging"
camp18 = "diabprod DIAB Rework"


try:
    driver_path= r"C:\Program Files\Google\chromedriver-win64\chromedriver.exe"
    service = Service(driver_path)
    driver = webdriver.Chrome(service=service)
    driver.implicitly_wait(30)
    driver.verificationErrors = []
    driver.accept_next_alert = True
# Enter the link to access and credentials
    driver.get("https://manage.callshaper.com/Report/Team")
    driver.find_element("id", "email").send_keys("*insert email")
    driver.find_element("id", "password").send_keys("*insert password*")
    time.sleep(0.5)
    driver.find_element(By.XPATH, "//button[@class='btn btn-inverse']").click()  # use XPATH -> add "//" -> change to single quotes "''" inside bracket
    time.sleep(0.5)
    print("Successful CDP Log In")
    
# CAMPAIGNS

# 11. DIAB Parachute
    driver.get(k)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp11 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp11}'")

# 12. DIAB VSA
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[1])
    print("Switch to the new tab")
    driver.get(l)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp12 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp12}'")

# 13. DIAB BT Load
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[2])
    print("Switch to the new tab")
    driver.get(m)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp13 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp13}'")
    
# 14. DIAB Dr Calls
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[3])
    print("Switch to the new tab")
    driver.get(n)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp14 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp14}'")
    
# 15. DIAB Medical Notes
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[4])
    print("Switch to the new tab")
    driver.get(o)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp15 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp15}'")

# 16. DIAB Patient Calls
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[5])
    print("Switch to the new tab")
    driver.get(p)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp16 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp16}'")

# 17. DIAB Held Aging
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[6])
    print("Switch to the new tab")
    driver.get(q)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp17 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp17}'")

# 18. DIAB Rework
    driver.execute_script("window.open('');")
    driver.switch_to.window(driver.window_handles[7])
    print("Switch to the new tab")
    driver.get(r)
    driver.find_element(By.XPATH, xpath).click()
    time.sleep(5) # Wait for download before renaming
    file_name = get_most_recent_file(download_path)
    new_file_name = os.path.join(download_path, camp18 + f".csv")
    os.rename(file_name, new_file_name)
    time.sleep(0.5)
    print(f"Succesfully downloaded '{camp18}'")

    print("Done Exporting 8 DIAB Prod Files")


except Exception as e:
   print(f"An error occurred: {e}")
# finally:
#  driver.quit()

# MOVE FILES TO HELD PROD CAMP FILES FOLDER

# Use glob to find files containing "AH" (case-insensitive)
search_pattern = os.path.join(download_path, "*diabprod*") # * is a wildcard
files_to_move = glob.glob(search_pattern)


if files_to_move:
    print(f"Found {len(files_to_move)} files to move:")
    for file_path in files_to_move:
        print(f" - {file_path}")

        try:
            # Extract just the filename for the destination path
            file_name = os.path.basename(file_path)
            destination_path = os.path.join(diab_prod_path, file_name)

            # Move the file
            shutil.move(file_path, destination_path)
            print(f"Moved '{file_name}' to '{diab_prod_path}'")

        except Exception as e:
            print(f"Error moving '{file_path}': {e}")

else:
    print("No files found matching the criteria.")

friday = (datetime.now() - timedelta(days=3)).strftime('%Y%m%d')
print(f"DONE " + friday)
# Out:
# Found files containing 'diabprod':
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB BT Load.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB BT Load.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Dr Calls.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Dr Calls.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Held Aging.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Held Aging.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Medical Notes.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Medical Notes.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Parachute.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Parachute.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Patient Calls.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Patient Calls.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Rework.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB Rework.csv
# - C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB VSA.csv
#   Deleted: C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES\diabprod DIAB VSA.csv
# Successful CDP Log In
# Succesfully downloaded 'diabprod DIAB Parachute'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB VSA'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB BT Load'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Dr Calls'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Medical Notes'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Patient Calls'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Held Aging'
# Switch to the new tab
# Succesfully downloaded 'diabprod DIAB Rework'
# Done Exporting 4 DIAB Prod Files
# Found 8 files to move:
#  - C:/Users/Administrator/Downloads\diabprod DIAB BT Load.csv
# Moved 'diabprod DIAB BT Load.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Dr Calls.csv
# Moved 'diabprod DIAB Dr Calls.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Held Aging.csv
# Moved 'diabprod DIAB Held Aging.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Medical Notes.csv
# Moved 'diabprod DIAB Medical Notes.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Parachute.csv
# Moved 'diabprod DIAB Parachute.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Patient Calls.csv
# Moved 'diabprod DIAB Patient Calls.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB Rework.csv
# Moved 'diabprod DIAB Rework.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
#  - C:/Users/Administrator/Downloads\diabprod DIAB VSA.csv
# Moved 'diabprod DIAB VSA.csv' to 'C:\Users\Administrator\Downloads\DIAB PROD CAMP FILES'
# DONE 20250912
